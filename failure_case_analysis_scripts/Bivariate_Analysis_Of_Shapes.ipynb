# %%
import pandas as pd
from pylab import rcParams
import seaborn as sns
from scipy.stats.stats import kendalltau
# Out:
# <ipython-input-21-8a040c07f7e8>:4: DeprecationWarning: Please use `kendalltau` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import kendalltau

# %%
# Data Visualisation Settings
# %matplotlib inline
rcParams['figure.figsize'] = 5,4
sns.set_style('whitegrid')

# %%
data = pd.read_csv('desk_0001.txt',sep=',',header=None)
data = data.loc[:,:2]
data.columns =['x','y','z']
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

sns.pairplot(data)

# %%
# let's check for the overall correlation
corr = data.corr(method='kendall')
rcParams['figure.figsize'] = 6,3
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values,
           cmap="YlGnBu",
          annot=True)
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#                   x             y             z
# count  10000.000000  10000.000000  10000.000000
# mean      -0.005049     -0.041086      0.181888
# std        0.371971      0.174837      0.530903
# min       -0.576000     -0.398700     -0.797100
# 25%       -0.346875     -0.186000     -0.288300
# 50%       -0.008443     -0.018850      0.320700
# 75%        0.338300      0.078810      0.679400
# max        0.576000      0.364100      0.744800

# %%
# let's check for the overall correlation
'''corr = combined.corr(method='kendall')
rcParams['figure.figsize'] = 10,7
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values,
           cmap="YlGnBu",
          annot=True)'''
# Out:
# <Axes: >

# %% [markdown]
# # comparison Chair vs Sink

# %%
# let's check for the overall correlation
'''corr = combined.corr(method='kendall')
rcParams['figure.figsize'] = 10,7
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values,
           cmap="YlGnBu",
          annot=True)'''
# Out:
# <Axes: >

# %% [markdown]
# # comparison Chair vs Sofa

# %%
#combined=pd.concat((data,data1),axis=1)

# %%
# let's check for the overall correlation
'''corr = combined.corr(method='kendall')
rcParams['figure.figsize'] = 10,7
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values,
           cmap="YlGnBu",
          annot=True)'''
# Out:
# <Axes: >
