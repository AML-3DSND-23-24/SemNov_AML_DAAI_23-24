# %%
# !pip3 install ipympl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.3/516.3 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 37.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb
from scipy.stats.stats import kendalltau

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
# Data Visualisation Settings
# %matplotlib inline
rcParams['figure.figsize'] = 5,4
sb.set_style('whitegrid')

# %%
import plotly.express as px

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %%
# for creating a responsive plot
# %matplotlib widget

# importing required libraries
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv('chair_0144.txt',sep=',')
data1.columns=['x','y','z','r','g','b']
data1 = data1[['x','y','z']]
data1
# Out:
#             x        y        z
# 0    -0.51160 -0.80560 -0.21930
# 1    -0.37910  0.71870  0.56880
# 2     0.51510 -0.82210 -0.22830
# 3    -0.53010  0.09320 -0.08635
# 4     0.38410  0.71080  0.43150
# ...       ...      ...      ...
# 9994 -0.32200 -0.01976  0.42260
# 9995 -0.03926 -0.68300  0.02726
# 9996 -0.44870  0.11400  0.11640
# 9997  0.32050  0.40270  0.37010
# 9998  0.22940 -0.73130  0.35520
#
# [9999 rows x 3 columns]

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
fig = px.scatter_3d(data1, x='x', y='y', z='z')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data2 = pd.read_csv('sofa_0578.txt',sep=',')
data2.columns=['x','y','z','x1','x2','x3']
data2 = data2[['x','y','z']]
data2
# Out:
#             x       y       z
# 0    -0.36900 -0.1854  0.9085
# 1     0.36890  0.3631  0.7163
# 2    -0.36930 -0.1788 -0.9109
# 3     0.34450  0.3626 -0.8452
# 4     0.25590 -0.3098 -0.7907
# ...       ...     ...     ...
# 9994  0.18460 -0.1866  0.9066
# 9995  0.09467 -0.1855  0.9106
# 9996 -0.25670 -0.3096 -0.7790
# 9997 -0.26750 -0.3091  0.7798
# 9998  0.23520 -0.3069  0.7822
#
# [9999 rows x 3 columns]

# %%
fig1 = px.scatter_3d(data2, x='x', y='y', z='z')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install ellipsis

# %%
# !pip install open3d

# %%
import pandas as pd
data2 = pd.read_csv('bed_0005.txt',sep=',')
data2.columns=['x','y','z','x1','x2','x3']
data2 = data2[['x','y','z']]
data2
# Out:
#             x       y       z
# 0     0.58480  0.2285  0.7727
# 1     0.58720 -0.2095 -0.7787
# 2    -0.18750 -0.2419  0.7722
# 3     0.35750 -0.2437  0.0733
# 4    -0.25560 -0.1621 -0.7796
# ...       ...     ...     ...
# 9994 -0.59030 -0.1536 -0.2162
# 9995  0.59070 -0.1025 -0.5568
# 9996  0.58900 -0.1706 -0.2843
# 9997  0.05946 -0.2049 -0.7614
# 9998 -0.60540 -0.1569  0.2170
#
# [9999 rows x 3 columns]

# %%
fig1 = px.scatter_3d(data2, x='x', y='y', z='z')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
